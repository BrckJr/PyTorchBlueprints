# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Creating Multi-Class Data ##

# %%
# Set the hyperparameters for the data creation
NUM_CLASSES = 4
NUM_FEATURES = 2
RANDOM_SEED = 42

# 1. Create data
X_blob, y_blob = make_blobs(n_samples=1000,
                           n_features=NUM_FEATURES,
                           centers=NUM_CLASSES,
                           cluster_std=1.5,
                           random_state=RANDOM_SEED)

# 2. Turn the data into tensors
X_blob = torch.from_numpy(X_blob).type(torch.float)
# torch.LongTensor creates a 64-bit integer (dtype) on the CPU
y_blob = torch.from_numpy(y_blob).type(torch.LongTensor)

# 3. Training-Test-Split
X_blob_train, X_blob_test, y_blob_train, y_blob_test = train_test_split(X_blob, y_blob, test_size=0.2, random_state=RANDOM_SEED)

# 4. Visualize the data
def visualize_data():
    plt.figure(figsize=(7,5))
    plt.scatter(X_blob[:,0], X_blob[:, 1], c=y_blob, s=2, cmap=plt.cm.RdYlBu)

# %%
visualize_data()

# %% [markdown]
# ## 2. Building a Model ##

# %%
# Device Agnostic Programming
device = "mps" if torch.backends.mps.is_available() else "cpu"

# 1. Construct model class
class MulticlassClassificationModel(nn.Module):
    def __init__(self, NO_CLASSES):
        super().__init__()

        # Create a neural network with two hidden layers
        # Input is two-dimensional, output one dimensional
        self.layer_1 = nn.Linear(in_features=2, out_features=10)
        self.layer_2 = nn.Linear(in_features=10, out_features=10)
        self.layer_3 = nn.Linear(in_features=10, out_features=NO_CLASSES)
        self.relu = nn.ReLU()
        
    # Define the calculation in the forward pass
    def forward(self, x):
        return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

# %%
model = MulticlassClassificationModel(4).to(device)
print(model)
# Out:
# MulticlassClassificationModel(
#   (layer_1): Linear(in_features=2, out_features=10, bias=True)
#   (layer_2): Linear(in_features=10, out_features=10, bias=True)
#   (layer_3): Linear(in_features=10, out_features=4, bias=True)
#   (relu): ReLU()
# )

# %%
# Defining the loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.1)

# Calculate accuracy based on a prediction and ground truth
def accuracy_function(y_true, y_pred):
    # torch.eq calculates where the two arguments are equal,
    # this gets summed up and turned into a python number
    correct = torch.eq(y_true, y_pred).sum().item()
    # Return the percentage of correctly classified elements
    return (correct / len(y_pred)) * 100

# %%
# Build training and evaluation loop

torch.manual_seed(42)
epochs = 101

# Put data to target device
X_blob_train, y_blob_train = X_blob_train.to(device), y_blob_train.to(device)
X_blob_test, y_blob_test = X_blob_test.to(device), y_blob_test.to(device)

for epoch in range(epochs):
    
    """
    Training
    """
    model.train()
    
    # 1. Forward Pass
    y_logits = model(X_blob_train)
    # Take the class with highest probability as prediction
    y_pred = torch.argmax(torch.softmax(y_logits, dim=1), dim=1)
  
    # 2. Calulcate loss and accuracy
    #    Here we can use the raw logits because we used nn.BCEWithLogitsLoss before
    loss = loss_function(y_logits, y_blob_train)
    acc = accuracy_function(y_true=y_blob_train,
                      y_pred=y_pred)

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backwards
    loss.backward()

    # 5. Optimizer step
    optimizer.step()


    """
    Testing
    """
    model.eval()
    with torch.inference_mode():
        
        # 1. Forward pass
        test_logits = model(X_blob_test).squeeze()
        test_pred = torch.argmax(torch.softmax(test_logits, dim=1), dim=1)

        # 2. Calulcate loss and accuracy
        test_loss = loss_function(test_logits, y_blob_test)
        test_acc = accuracy_function(y_true=y_blob_test,
                             y_pred=test_pred)

    # Print current state every 10 epochs
    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Loss: {loss:.5f}, Acc: {acc:.2f}% | Test Loss: {test_loss:.5f}, Test Acc: {test_acc:.2f}%")
# Out:
# Epoch: 0 | Loss: 1.50867, Acc: 2.75% | Test Loss: 1.41169, Test Acc: 1.50%
# Epoch: 10 | Loss: 1.04802, Acc: 51.00% | Test Loss: 1.04506, Test Acc: 45.00%
# Epoch: 20 | Loss: 0.53716, Acc: 86.75% | Test Loss: 0.53727, Test Acc: 89.50%
# Epoch: 30 | Loss: 0.36114, Acc: 96.88% | Test Loss: 0.36511, Test Acc: 97.00%
# Epoch: 40 | Loss: 0.22148, Acc: 99.00% | Test Loss: 0.21278, Test Acc: 99.50%
# Epoch: 50 | Loss: 0.11025, Acc: 99.00% | Test Loss: 0.10103, Test Acc: 99.50%
# Epoch: 60 | Loss: 0.06915, Acc: 99.00% | Test Loss: 0.06087, Test Acc: 99.50%
# Epoch: 70 | Loss: 0.05338, Acc: 99.00% | Test Loss: 0.04512, Test Acc: 99.50%
# Epoch: 80 | Loss: 0.04561, Acc: 99.00% | Test Loss: 0.03717, Test Acc: 99.50%
# Epoch: 90 | Loss: 0.04103, Acc: 99.00% | Test Loss: 0.03242, Test Acc: 99.50%
# Epoch: 100 | Loss: 0.03805, Acc: 99.00% | Test Loss: 0.02926, Test Acc: 99.50%

# %%
from helper_functions import plot_predictions, plot_decision_boundary

# Visualize the decision boundaries for the training and test set
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model, X_blob_train, y_blob_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model, X_blob_test, y_blob_test)

# %% [markdown]
# ## 3. Making predictions ##

# %%
model.to(device)
model.eval()
with torch.inference_mode():
    y_pred_new = torch.argmax(torch.softmax(model(X_blob_test), dim=1), dim=1)

print(y_pred_new[:5])
plt.figure(figsize=(7,5))
plt.scatter(X_blob_test.cpu()[:,0], X_blob_test.cpu()[:, 1],  c=y_pred_new.cpu(), s=5, cmap=plt.cm.Set1)
# Out:
# tensor([1, 3, 2, 1, 0], device='mps:0')

# %% [markdown]
# ## ADD-ON: Fitting a non-linear data set ##

# %%
# Code for creating a spiral dataset from CS231n
import numpy as np
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D)) # data matrix (each row = single example)
y = np.zeros(N*K, dtype='uint8') # class labels
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j
# lets visualize the data
plt.scatter(X[:, 0], X[:, 1], c=y, s=4, cmap=plt.cm.Set1)
plt.show()

X = torch.from_numpy(X).type(torch.float) # features as float32
y = torch.from_numpy(y).type(torch.LongTensor)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)

# %%
# Device Agnostic Programming
device = "mps" if torch.backends.mps.is_available() else "cpu"

# 1. Construct model class
class MulticlassClassificationModel(nn.Module):
    def __init__(self):
        super().__init__()

        # Create a neural network with two hidden layers
        # Input is two-dimensional, output one dimensional
        self.layer_1 = nn.Linear(in_features=2, out_features=10)
        self.layer_2 = nn.Linear(in_features=10, out_features=10)
        self.layer_3 = nn.Linear(in_features=10, out_features=3)
        self.relu = nn.ReLU()
        
    # Define the calculation in the forward pass
    def forward(self, x):
        return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

# %%
model2 = MulticlassClassificationModel().to(device)
print(model2)
# Out:
# MulticlassClassificationModel(
#   (layer_1): Linear(in_features=2, out_features=10, bias=True)
#   (layer_2): Linear(in_features=10, out_features=10, bias=True)
#   (layer_3): Linear(in_features=10, out_features=3, bias=True)
#   (relu): ReLU()
# )

# %%
# Defining the loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model2.parameters(), lr=0.01)

# !pip -q install torchmetrics
# Calculate accuracy based on a prediction and ground truth
from torchmetrics import Accuracy
accuracy_function = Accuracy(task="multiclass", num_classes=3).to(device)

# %%
# Build training and evaluation loop

torch.manual_seed(42)
epochs = 1001

# Put data to target device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

for epoch in range(epochs):
    
    """
    Training
    """
    model2.train()
    
    # 1. Forward Pass
    y_logits = model2(X_train)
    # Take the class with highest probability as prediction
    y_pred = torch.argmax(torch.softmax(y_logits, dim=1), dim=1)
  
    # 2. Calulcate loss and accuracy
    #    Here we can use the raw logits because we used nn.BCEWithLogitsLoss before
    loss = loss_function(y_logits, y_train)
    acc = accuracy_function(y_pred, y_train)

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backwards
    loss.backward()

    # 5. Optimizer step
    optimizer.step()


    """
    Testing
    """
    model2.eval()
    with torch.inference_mode():
        
        # 1. Forward pass
        test_logits = model2(X_test)
        test_pred = torch.argmax(torch.softmax(test_logits, dim=1), dim=1)

        # 2. Calulcate loss and accuracy
        test_loss = loss_function(test_logits, y_test)
        test_acc = accuracy_function(test_pred, y_test)

    # Print current state every 10 epochs
    if epoch % 100 == 0:
        print(f"Epoch: {epoch} | Loss: {loss:.5f}, Acc: {acc:.2f}% | Test Loss: {test_loss:.5f}, Test Acc: {test_acc:.2f}%")
# Out:
# Epoch: 0 | Loss: 1.11747, Acc: 0.32% | Test Loss: 1.10764, Test Acc: 0.37%
# Epoch: 100 | Loss: 0.59651, Acc: 0.66% | Test Loss: 0.62073, Test Acc: 0.63%
# Epoch: 200 | Loss: 0.40839, Acc: 0.80% | Test Loss: 0.46267, Test Acc: 0.77%
# Epoch: 300 | Loss: 0.19463, Acc: 0.94% | Test Loss: 0.21689, Test Acc: 0.93%
# Epoch: 400 | Loss: 0.13437, Acc: 0.95% | Test Loss: 0.14205, Test Acc: 0.95%
# Epoch: 500 | Loss: 0.08914, Acc: 0.98% | Test Loss: 0.06863, Test Acc: 0.98%
# Epoch: 600 | Loss: 0.06653, Acc: 0.98% | Test Loss: 0.06853, Test Acc: 0.98%
# Epoch: 700 | Loss: 0.05488, Acc: 0.98% | Test Loss: 0.06156, Test Acc: 0.97%
# Epoch: 800 | Loss: 0.04675, Acc: 0.98% | Test Loss: 0.06081, Test Acc: 0.97%
# Epoch: 900 | Loss: 0.04215, Acc: 0.98% | Test Loss: 0.06277, Test Acc: 0.95%
# Epoch: 1000 | Loss: 0.03920, Acc: 0.98% | Test Loss: 0.06275, Test Acc: 0.95%

# %%
from helper_functions import plot_predictions, plot_decision_boundary

# Visualize the decision boundaries for the training and test set
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model2, X_train, y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model2, X_test, y_test)
